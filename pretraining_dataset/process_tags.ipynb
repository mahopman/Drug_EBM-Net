# %% [markdown]
# <a href="https://colab.research.google.com/github/mahopman/IEBM-Net/blob/main/pretraining_dataset/process_tags.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
__author__ = 'Qiao Jin'
__editor__ = 'Mia Hopman'

# %%
local_path = '/content/drive/MyDrive/MS_DataScience/DS595/IEBM-Net_Data'
pretraining_dataset_path = f'{local_path}/pretraining_dataset'

# %%
def reversed(words, label):

	all_rev = (words + ['MASK'])[::-1]

	mask_idx = [idx for idx, word in enumerate(all_rev) if word == '[MASK]']
	mask_idx = [0] + mask_idx + [len(all_rev)]

	for i, idx in enumerate(mask_idx[:-1]):
		all_rev[idx+1: mask_idx[i+1]] = all_rev[idx+1: mask_idx[i+1]][::-1]

	all_rev = all_rev[1:]

	if label in up2down:
		rev_label = up2down[label]
	elif label in down2up:
		rev_label = down2up[label]
	else:
		rev_label = label

	return all_rev, rev_label

# %%
def get_label(pos, indices, label2ctr):
	ind_words = [pos[ind][0] for ind in indices]

	if len(ind_words) == 2:
		label = ind_words[0].lower()
		if label not in label2idx:
			return False
		else:
			label2ctr[label] += 1
			return label2idx[label]
	else:
		if ind_words[-1] == 'than':
			return False
		else:
			label2ctr['nodiff'] += 1
			return label2idx['nodiff']

# %%
import json
import random as rd
import glob
import os

# process labels
ups = ['better', 'greater', 'higher', 'later', 'more', 'faster', 'older', 'longer', \
		'larger', 'broader', 'wider', 'stronger', 'deeper', 'more', 'commoner', 'richer', \
		'further', 'bigger']
downs = ['worse', 'smaller', 'lower', 'earlier', 'less', 'slower', 'younger', 'shorter', \
		'smaller', 'narrower', 'narrower', 'weaker', 'shallower', 'fewer', 'rarer', 'poorer', \
		'closer', 'smaller']
sims = ['nodiff', 'similar']

label_set =  list(set(downs)) + list(set(sims)) + list(set(ups))

label2idx = {label: idx for idx, label in enumerate(label_set)}
label2idx['similarly'] = label2idx['similar']
label2idx['similarity'] = label2idx['similar']
label2idx['similarities'] = label2idx['similar']
label2idx['farther'] = label2idx['further']

label2ctr = {k: 0 for k in list(label2idx)}

up2down = {label2idx[k]: label2idx[v] for k, v in zip(ups, downs)}
down2up = {label2idx[k]: label2idx[v] for k, v in zip(downs, ups)}

intervention2ids = json.load(open(f'{pretraining_dataset_path}/intervention2ids.json'))
drug_pmids = intervention2ids['DRUG']

all_pmids = [pmid for key, pmids in intervention2ids.items() for pmid in pmids]
random_pmids = rd.sample(all_pmids, len(drug_pmids))

# start
output = []

removed = set(['CD'])
indicators = set(['significant', 'significantly', 'statistically', 'statistic', '%'])
sims = set(['similar', 'similarly', 'similarity', 'similarities'])

drug_pmids_final = set()
random_pmids_final = set()

files = glob.glob(f'{pretraining_dataset_path}/evidence/evidence_pos_*.json')

for file in files:
    chunk_id = file.split('/')[-1].split('.')[0].split('_')[-1]
    if not os.path.exists(file): continue
    data = json.load(open(file))

    for item in data:
        pmid = item['pmid']
        if pmid in drug_pmids or pmid in random_pmids:
            pos = item['pos']
            indices = item['indices']

            label = get_label(pos, indices, label2ctr)

            if not label: continue # lose about ~20%

            par_stack = []
            idx_stack = []
            lefts = []
            rights = []
            for idx, info in enumerate(pos):
                if info[0] in {'(', ')'}:
                    if not par_stack:
                        if info[0] == ')': continue
                        par_stack.append(info[0])
                        idx_stack.append(idx)
                    else:
                        if par_stack[-1] == info[0]:
                            par_stack.append(info[0])
                            idx_stack.append(idx)
                        else:
                            par_stack = par_stack[:-1]
                            lefts.append(idx_stack[-1])
                            rights.append(idx)
                            idx_stack = idx_stack[:-1]

            within_par = []
            if lefts and rights:
                for left, right in zip(lefts, rights):
                    within_par += list(range(left, right+1))

            # detect irrelavent subsentences
            dot_indices = [idx for idx, info in enumerate(pos) if info[0] == ',']
            outer_idx = []
            if dot_indices:
                left, right = min(item['indices']), max(item['indices'])
                # item['indices'] save the important indices
                dot_indices = [-1] + dot_indices + [len(pos)]
                # print(left, right, dot_indices)
                for i in range(len(dot_indices)-1):
                    if dot_indices[i] <= left < dot_indices[i+1]:
                        left_start = i
                    if dot_indices[i] <= right < dot_indices[i+1]:
                        right_start = i
                left = dot_indices[left_start]
                right = dot_indices[right_start+1]
                for i in range(len(pos)):
                    if i <= left or i >= right:
                        outer_idx.append(i)

		    # detect irrelavent show that / suggest that

            # RB before JJR in generally bad
            include_idx = []
            that_judged = False # only judge once
            for idx, i in enumerate(pos):
                if idx in outer_idx:
                    #print(i, '----------OUT')
                    pass
                elif idx+1 < len(pos) and (pos[idx+1][1] == 'JJR' or pos[idx+1][1] == 'RBR') and \
                    ((i[1] == 'RB' and i[0].lower() != 'not') \
                    or i[0].lower() == 'times'):
                    #print(i, '----------FRONT_RB')
                    pass
                elif idx in item['indices']:
                    #print(i, '----------DETECTED')
                    pass
                elif i[1] in removed:
                    #print(i, '----------TOREMOVE')
                    pass
                elif i[0].lower() in indicators:
                    #print(i, '----------INDICATOR')
                    pass
                elif idx in within_par:
                    #print(i, '----------INPAR')
                    pass
                elif not that_judged and i[0].lower() == 'that':
                    if idx < min(item['indices']):
                        #print(i, '----------THAT')
                        that_judged = True
                        include_idx = []
                else:
                    #print(i)
                    include_idx.append(idx)

            final_evidence = []
            for idx, i in enumerate(pos):

                if idx in include_idx:
                    final_evidence.append(i[0])
                else:
                    if  final_evidence and final_evidence[-1] != '[MASK]':
                        final_evidence.append('[MASK]')

            if not final_evidence: continue

            if final_evidence[-1] in ['.', '[MASK]']:
                final_evidence = final_evidence[:-1]

            # Make every word after [MASK] upper cased
            for idx, word in enumerate(final_evidence):
                if idx == 0 and word != '[MASK]':
                    final_evidence[idx] = word[0].upper() + word[1:]
                elif word == '[MASK]' and idx + 1 < len(final_evidence) and final_evidence[idx+1]:
                    final_evidence[idx+1] = final_evidence[idx+1][0].upper() + final_evidence[idx+1][1:]

            rev_evidence, rev_label = reversed(final_evidence, label)

            output.append({'pmid': pmid,
                    'pico': ' '.join(final_evidence), 'label': label,
                    'rev_pico': ' '.join(rev_evidence), 'rev_label': rev_label})
            if pmid in drug_pmids:
                drug_pmids_final.add(pmid)
            elif pmid in random_pmids:
                random_pmids_final.add(pmid)

    print('Processed chunk #%d. Got %d insts' % (int(chunk_id), len(output)))

with open(f'{pretraining_dataset_path}/evidence.json', 'w') as f:
	json.dump(output, f, indent=4)

with open(f'{pretraining_dataset_path}/evidence_pmids.json', 'w') as f:
	json.dump(list(drug_pmids_final), f, indent=4)

with open(f'{pretraining_dataset_path}/evidence_pmids_random.json', 'w') as f:
	json.dump(list(random_pmids_final), f, indent=4)
# Out:
# Processed chunk #657. Got 31 insts
# Processed chunk #658. Got 43 insts
# Processed chunk #659. Got 62 insts
# Processed chunk #660. Got 83 insts
# Processed chunk #661. Got 107 insts
# Processed chunk #715. Got 131 insts
# Processed chunk #663. Got 141 insts
# Processed chunk #664. Got 159 insts
# Processed chunk #665. Got 173 insts
# Processed chunk #667. Got 198 insts
# Processed chunk #666. Got 209 insts
# Processed chunk #669. Got 214 insts
# Processed chunk #668. Got 233 insts
# Processed chunk #670. Got 233 insts
# Processed chunk #671. Got 264 insts
# Processed chunk #672. Got 281 insts
# Processed chunk #673. Got 290 insts
# Processed chunk #674. Got 305 insts
# Processed chunk #676. Got 310 insts
# Processed chunk #675. Got 329 insts
# Processed chunk #677. Got 332 insts
# Processed chunk #678. Got 348 insts
# Processed chunk #679. Got 364 insts
# Processed chunk #681. Got 390 insts
# Processed chunk #680. Got 403 insts
# Processed chunk #682. Got 434 insts
# Processed chunk #683. Got 454 insts
# Processed chunk #684. Got 469 insts
# Processed chunk #685. Got 484 insts
# Processed chunk #686. Got 510 insts
# Processed chunk #687. Got 531 insts
# Processed chunk #688. Got 557 insts
# Processed chunk #689. Got 581 insts
# Processed chunk #690. Got 604 insts
# Processed chunk #691. Got 627 insts
# Processed chunk #692. Got 655 insts
# Processed chunk #693. Got 679 insts
# Processed chunk #694. Got 694 insts
# Processed chunk #695. Got 715 insts
# Processed chunk #696. Got 730 insts
# Processed chunk #697. Got 745 insts
# Processed chunk #698. Got 772 insts
# Processed chunk #699. Got 793 insts
# Processed chunk #700. Got 804 insts
# Processed chunk #701. Got 817 insts
# Processed chunk #702. Got 849 insts
# Processed chunk #703. Got 873 insts
# Processed chunk #704. Got 898 insts
# Processed chunk #705. Got 915 insts
# Processed chunk #706. Got 937 insts
# Processed chunk #707. Got 961 insts
# Processed chunk #708. Got 985 insts
# Processed chunk #709. Got 1005 insts
# Processed chunk #710. Got 1040 insts
# Processed chunk #711. Got 1061 insts
# Processed chunk #712. Got 1087 insts
# Processed chunk #713. Got 1113 insts
# Processed chunk #714. Got 1138 insts
# Processed chunk #768. Got 1171 insts
# Processed chunk #716. Got 1186 insts
# Processed chunk #717. Got 1204 insts
# Processed chunk #718. Got 1234 insts
# Processed chunk #2. Got 1234 insts
# Processed chunk #4. Got 1234 insts
# Processed chunk #3. Got 1234 insts
# Processed chunk #1. Got 1234 insts
# Processed chunk #6. Got 1234 insts
# Processed chunk #8. Got 1234 insts
# Processed chunk #5. Got 1234 insts
# Processed chunk #9. Got 1234 insts
# Processed chunk #7. Got 1234 insts
# Processed chunk #10. Got 1234 insts
# Processed chunk #13. Got 1234 insts
# Processed chunk #14. Got 1234 insts
# Processed chunk #11. Got 1234 insts
# Processed chunk #12. Got 1234 insts
# Processed chunk #15. Got 1234 insts
# Processed chunk #16. Got 1234 insts
# Processed chunk #18. Got 1234 insts
# Processed chunk #17. Got 1234 insts
# Processed chunk #21. Got 1234 insts
# Processed chunk #20. Got 1234 insts
# Processed chunk #19. Got 1234 insts
# Processed chunk #22. Got 1234 insts
# Processed chunk #23. Got 1234 insts
# Processed chunk #25. Got 1234 insts
# Processed chunk #24. Got 1234 insts
# Processed chunk #26. Got 1234 insts
# Processed chunk #79. Got 1234 insts
# Processed chunk #28. Got 1234 insts
# Processed chunk #27. Got 1234 insts
# Processed chunk #29. Got 1234 insts
# Processed chunk #30. Got 1234 insts
# Processed chunk #32. Got 1234 insts
# Processed chunk #31. Got 1234 insts
# Processed chunk #33. Got 1234 insts
# Processed chunk #34. Got 1234 insts
# Processed chunk #35. Got 1234 insts
# Processed chunk #36. Got 1234 insts
# Processed chunk #37. Got 1234 insts
# Processed chunk #38. Got 1234 insts
# Processed chunk #39. Got 1234 insts
# Processed chunk #40. Got 1234 insts
# Processed chunk #41. Got 1234 insts
# Processed chunk #42. Got 1234 insts
# Processed chunk #43. Got 1234 insts
# Processed chunk #44. Got 1234 insts
# Processed chunk #45. Got 1234 insts
# Processed chunk #46. Got 1234 insts
# Processed chunk #47. Got 1234 insts
# Processed chunk #48. Got 1234 insts
# Processed chunk #49. Got 1234 insts
# Processed chunk #50. Got 1234 insts
# Processed chunk #51. Got 1234 insts
# Processed chunk #52. Got 1234 insts
# Processed chunk #53. Got 1234 insts
# Processed chunk #54. Got 1234 insts
# Processed chunk #55. Got 1234 insts
# Processed chunk #56. Got 1234 insts
# Processed chunk #57. Got 1234 insts
# Processed chunk #58. Got 1234 insts
# Processed chunk #59. Got 1234 insts
# Processed chunk #60. Got 1234 insts
# Processed chunk #61. Got 1234 insts
# Processed chunk #62. Got 1234 insts
# Processed chunk #63. Got 1234 insts
# Processed chunk #64. Got 1234 insts
# Processed chunk #65. Got 1234 insts
# Processed chunk #66. Got 1234 insts
# Processed chunk #67. Got 1234 insts
# Processed chunk #68. Got 1234 insts
# Processed chunk #69. Got 1234 insts
# Processed chunk #70. Got 1234 insts
# Processed chunk #71. Got 1234 insts
# Processed chunk #72. Got 1234 insts
# Processed chunk #73. Got 1234 insts
# Processed chunk #74. Got 1234 insts
# Processed chunk #75. Got 1234 insts
# Processed chunk #76. Got 1234 insts
# Processed chunk #77. Got 1234 insts
# Processed chunk #78. Got 1234 insts
# Processed chunk #132. Got 1234 insts
# Processed chunk #80. Got 1234 insts
# Processed chunk #81. Got 1234 insts
# Processed chunk #82. Got 1234 insts
# Processed chunk #83. Got 1234 insts
# Processed chunk #85. Got 1234 insts
# Processed chunk #84. Got 1234 insts
# Processed chunk #86. Got 1234 insts
# Processed chunk #87. Got 1234 insts
# Processed chunk #88. Got 1234 insts
# Processed chunk #90. Got 1234 insts
# Processed chunk #89. Got 1234 insts
# Processed chunk #91. Got 1234 insts
# Processed chunk #92. Got 1234 insts
# Processed chunk #93. Got 1234 insts
# Processed chunk #94. Got 1234 insts
# Processed chunk #95. Got 1234 insts
# Processed chunk #96. Got 1234 insts
# Processed chunk #98. Got 1234 insts
# Processed chunk #97. Got 1234 insts
# Processed chunk #100. Got 1234 insts
# Processed chunk #101. Got 1234 insts
# Processed chunk #99. Got 1234 insts
# Processed chunk #102. Got 1234 insts
# Processed chunk #103. Got 1234 insts
# Processed chunk #106. Got 1234 insts
# Processed chunk #105. Got 1234 insts
# Processed chunk #104. Got 1234 insts
# Processed chunk #107. Got 1234 insts
# Processed chunk #108. Got 1234 insts
# Processed chunk #109. Got 1234 insts
# Processed chunk #110. Got 1234 insts
# Processed chunk #111. Got 1234 insts
# Processed chunk #112. Got 1234 insts
# Processed chunk #114. Got 1234 insts
# Processed chunk #113. Got 1234 insts
# Processed chunk #115. Got 1234 insts
# Processed chunk #116. Got 1234 insts
# Processed chunk #117. Got 1234 insts
# Processed chunk #118. Got 1234 insts
# Processed chunk #119. Got 1234 insts
# Processed chunk #120. Got 1234 insts
# Processed chunk #121. Got 1234 insts
# Processed chunk #122. Got 1234 insts
# Processed chunk #123. Got 1234 insts
# Processed chunk #124. Got 1234 insts
# Processed chunk #125. Got 1234 insts
# Processed chunk #126. Got 1234 insts
# Processed chunk #127. Got 1234 insts
# Processed chunk #128. Got 1234 insts
# Processed chunk #129. Got 1234 insts
# Processed chunk #130. Got 1234 insts
# Processed chunk #131. Got 1234 insts
# Processed chunk #185. Got 1234 insts
# Processed chunk #133. Got 1234 insts
# Processed chunk #134. Got 1234 insts
# Processed chunk #135. Got 1234 insts
# Processed chunk #136. Got 1234 insts
# Processed chunk #137. Got 1234 insts
# Processed chunk #138. Got 1234 insts
# Processed chunk #139. Got 1234 insts
# Processed chunk #140. Got 1234 insts
# Processed chunk #141. Got 1234 insts
# Processed chunk #142. Got 1234 insts
# Processed chunk #143. Got 1234 insts
# Processed chunk #144. Got 1234 insts
# Processed chunk #145. Got 1234 insts
# Processed chunk #146. Got 1234 insts
# Processed chunk #147. Got 1234 insts
# Processed chunk #148. Got 1234 insts
# Processed chunk #149. Got 1234 insts
# Processed chunk #150. Got 1234 insts
# Processed chunk #151. Got 1234 insts
# Processed chunk #152. Got 1234 insts
# Processed chunk #153. Got 1234 insts
# Processed chunk #154. Got 1234 insts
# Processed chunk #155. Got 1234 insts
# Processed chunk #156. Got 1234 insts
# Processed chunk #157. Got 1234 insts
# Processed chunk #158. Got 1234 insts
# Processed chunk #159. Got 1234 insts
# Processed chunk #160. Got 1234 insts
# Processed chunk #161. Got 1234 insts
# Processed chunk #162. Got 1234 insts
# Processed chunk #163. Got 1234 insts
# Processed chunk #164. Got 1234 insts
# Processed chunk #165. Got 1234 insts
# Processed chunk #166. Got 1234 insts
# Processed chunk #167. Got 1234 insts
# Processed chunk #168. Got 1234 insts
# Processed chunk #169. Got 1234 insts
# Processed chunk #170. Got 1234 insts
# Processed chunk #171. Got 1234 insts
# Processed chunk #172. Got 1234 insts
# Processed chunk #173. Got 1234 insts
# Processed chunk #174. Got 1234 insts
# Processed chunk #175. Got 1234 insts
# Processed chunk #176. Got 1234 insts
# Processed chunk #177. Got 1234 insts
# Processed chunk #178. Got 1234 insts
# Processed chunk #179. Got 1234 insts
# Processed chunk #180. Got 1234 insts
# Processed chunk #181. Got 1234 insts
# Processed chunk #182. Got 1234 insts
# Processed chunk #183. Got 1234 insts
# Processed chunk #184. Got 1234 insts
# Processed chunk #238. Got 1234 insts
# Processed chunk #186. Got 1234 insts
# Processed chunk #187. Got 1234 insts
# Processed chunk #188. Got 1234 insts
# Processed chunk #189. Got 1234 insts
# Processed chunk #190. Got 1234 insts
# Processed chunk #191. Got 1234 insts
# Processed chunk #192. Got 1234 insts
# Processed chunk #193. Got 1234 insts
# Processed chunk #194. Got 1234 insts
# Processed chunk #195. Got 1234 insts
# Processed chunk #196. Got 1234 insts
# Processed chunk #197. Got 1234 insts
# Processed chunk #198. Got 1234 insts
# Processed chunk #199. Got 1234 insts
# Processed chunk #200. Got 1234 insts
# Processed chunk #201. Got 1234 insts
# Processed chunk #202. Got 1234 insts
# Processed chunk #203. Got 1234 insts
# Processed chunk #204. Got 1234 insts
# Processed chunk #205. Got 1234 insts
# Processed chunk #206. Got 1234 insts
# Processed chunk #207. Got 1234 insts
# Processed chunk #208. Got 1234 insts
# Processed chunk #209. Got 1234 insts
# Processed chunk #210. Got 1234 insts
# Processed chunk #211. Got 1234 insts
# Processed chunk #212. Got 1234 insts
# Processed chunk #213. Got 1234 insts
# Processed chunk #215. Got 1234 insts
# Processed chunk #214. Got 1234 insts
# Processed chunk #216. Got 1234 insts
# Processed chunk #217. Got 1234 insts
# Processed chunk #218. Got 1234 insts
# Processed chunk #719. Got 1240 insts
# Processed chunk #720. Got 1263 insts
# Processed chunk #721. Got 1289 insts
# Processed chunk #722. Got 1308 insts
# Processed chunk #724. Got 1332 insts
# Processed chunk #723. Got 1361 insts
# Processed chunk #726. Got 1395 insts
# Processed chunk #725. Got 1426 insts
# Processed chunk #727. Got 1446 insts
# Processed chunk #728. Got 1469 insts
# Processed chunk #729. Got 1481 insts
# Processed chunk #730. Got 1501 insts
# Processed chunk #731. Got 1528 insts
# Processed chunk #732. Got 1547 insts
# Processed chunk #733. Got 1575 insts
# Processed chunk #734. Got 1598 insts
# Processed chunk #735. Got 1635 insts
# Processed chunk #736. Got 1645 insts
# Processed chunk #737. Got 1670 insts
# Processed chunk #738. Got 1694 insts
# Processed chunk #739. Got 1729 insts
# Processed chunk #740. Got 1750 insts
# Processed chunk #741. Got 1773 insts
# Processed chunk #742. Got 1796 insts
# Processed chunk #744. Got 1816 insts
# Processed chunk #745. Got 1844 insts
# Processed chunk #743. Got 1865 insts
# Processed chunk #746. Got 1884 insts
# Processed chunk #747. Got 1903 insts
# Processed chunk #748. Got 1928 insts
# Processed chunk #749. Got 1964 insts
# Processed chunk #750. Got 1982 insts
# Processed chunk #753. Got 2011 insts
# Processed chunk #751. Got 2035 insts
# Processed chunk #752. Got 2069 insts
# Processed chunk #754. Got 2097 insts
# Processed chunk #755. Got 2121 insts
# Processed chunk #756. Got 2138 insts
# Processed chunk #758. Got 2164 insts
# Processed chunk #757. Got 2183 insts
# Processed chunk #759. Got 2210 insts
# Processed chunk #761. Got 2243 insts
# Processed chunk #760. Got 2272 insts
# Processed chunk #762. Got 2291 insts
# Processed chunk #763. Got 2314 insts
# Processed chunk #764. Got 2340 insts
# Processed chunk #765. Got 2354 insts
# Processed chunk #766. Got 2385 insts
# Processed chunk #767. Got 2409 insts
# Processed chunk #821. Got 2452 insts
# Processed chunk #769. Got 2468 insts
# Processed chunk #770. Got 2488 insts
# Processed chunk #771. Got 2526 insts
# Processed chunk #772. Got 2553 insts
# Processed chunk #773. Got 2572 insts
# Processed chunk #774. Got 2592 insts
# Processed chunk #775. Got 2613 insts
# Processed chunk #776. Got 2640 insts
# Processed chunk #778. Got 2669 insts
# Processed chunk #777. Got 2694 insts
# Processed chunk #779. Got 2721 insts
# Processed chunk #780. Got 2733 insts
# Processed chunk #782. Got 2761 insts
# Processed chunk #781. Got 2783 insts
# Processed chunk #784. Got 2810 insts
# Processed chunk #783. Got 2823 insts
# Processed chunk #785. Got 2843 insts
# Processed chunk #786. Got 2859 insts
# Processed chunk #787. Got 2898 insts
# Processed chunk #788. Got 2930 insts
# Processed chunk #789. Got 2946 insts
# Processed chunk #790. Got 2973 insts
# Processed chunk #792. Got 2999 insts
# Processed chunk #791. Got 3029 insts
# Processed chunk #793. Got 3061 insts
# Processed chunk #794. Got 3106 insts
# Processed chunk #796. Got 3151 insts
# Processed chunk #795. Got 3180 insts
# Processed chunk #797. Got 3210 insts
# Processed chunk #798. Got 3247 insts
# Processed chunk #799. Got 3288 insts
# Processed chunk #801. Got 3321 insts
# Processed chunk #800. Got 3358 insts
# Processed chunk #802. Got 3383 insts
# Processed chunk #803. Got 3413 insts
# Processed chunk #805. Got 3447 insts
# Processed chunk #804. Got 3473 insts
# Processed chunk #806. Got 3511 insts
# Processed chunk #809. Got 3548 insts
# Processed chunk #807. Got 3588 insts
# Processed chunk #808. Got 3612 insts
# Processed chunk #810. Got 3632 insts
# Processed chunk #812. Got 3665 insts
# Processed chunk #813. Got 3697 insts
# Processed chunk #811. Got 3734 insts
# Processed chunk #814. Got 3755 insts
# Processed chunk #815. Got 3777 insts
# Processed chunk #816. Got 3816 insts
# Processed chunk #817. Got 3847 insts
# Processed chunk #818. Got 3878 insts
# Processed chunk #819. Got 3913 insts
# Processed chunk #820. Got 3947 insts
# Processed chunk #847. Got 4004 insts
# Processed chunk #822. Got 4040 insts
# Processed chunk #824. Got 4073 insts
# Processed chunk #823. Got 4103 insts
# Processed chunk #825. Got 4119 insts
# Processed chunk #826. Got 4149 insts
# Processed chunk #827. Got 4190 insts
# Processed chunk #828. Got 4218 insts
# Processed chunk #829. Got 4248 insts
# Processed chunk #830. Got 4270 insts
# Processed chunk #831. Got 4301 insts
# Processed chunk #832. Got 4335 insts
# Processed chunk #833. Got 4380 insts
# Processed chunk #834. Got 4403 insts
# Processed chunk #837. Got 4436 insts
# Processed chunk #836. Got 4462 insts
# Processed chunk #835. Got 4497 insts
# Processed chunk #838. Got 4544 insts
# Processed chunk #839. Got 4578 insts
# Processed chunk #840. Got 4614 insts
# Processed chunk #841. Got 4646 insts
# Processed chunk #842. Got 4683 insts
# Processed chunk #844. Got 4748 insts
# Processed chunk #843. Got 4795 insts
# Processed chunk #845. Got 4838 insts
# Processed chunk #846. Got 4877 insts
# Processed chunk #848. Got 4927 insts
# Processed chunk #874. Got 4961 insts
# Processed chunk #849. Got 5001 insts
# Processed chunk #850. Got 5045 insts
# Processed chunk #851. Got 5071 insts
# Processed chunk #852. Got 5101 insts
# Processed chunk #853. Got 5138 insts
# Processed chunk #854. Got 5174 insts
# Processed chunk #856. Got 5202 insts
# Processed chunk #855. Got 5231 insts
# Processed chunk #858. Got 5264 insts
# Processed chunk #857. Got 5303 insts
# Processed chunk #860. Got 5340 insts
# Processed chunk #861. Got 5373 insts
# Processed chunk #859. Got 5403 insts
# Processed chunk #862. Got 5441 insts
# Processed chunk #863. Got 5493 insts
# Processed chunk #864. Got 5539 insts
# Processed chunk #866. Got 5576 insts
# Processed chunk #865. Got 5601 insts
# Processed chunk #867. Got 5643 insts
# Processed chunk #868. Got 5684 insts
# Processed chunk #869. Got 5710 insts
# Processed chunk #870. Got 5756 insts
# Processed chunk #871. Got 5793 insts
# Processed chunk #872. Got 5827 insts
# Processed chunk #873. Got 5853 insts
# Processed chunk #927. Got 5886 insts
# Processed chunk #875. Got 5922 insts
# Processed chunk #876. Got 5957 insts
# Processed chunk #877. Got 5990 insts
# Processed chunk #878. Got 6029 insts
# Processed chunk #879. Got 6074 insts
# Processed chunk #880. Got 6110 insts
# Processed chunk #881. Got 6149 insts
# Processed chunk #882. Got 6177 insts
# Processed chunk #883. Got 6229 insts
# Processed chunk #884. Got 6254 insts
# Processed chunk #885. Got 6282 insts
# Processed chunk #886. Got 6317 insts
# Processed chunk #887. Got 6344 insts
# Processed chunk #888. Got 6379 insts
# Processed chunk #889. Got 6413 insts
# Processed chunk #890. Got 6449 insts
# Processed chunk #891. Got 6489 insts
# Processed chunk #892. Got 6517 insts
# Processed chunk #893. Got 6552 insts
# Processed chunk #894. Got 6590 insts
# Processed chunk #895. Got 6611 insts
# Processed chunk #897. Got 6649 insts
# Processed chunk #896. Got 6678 insts
# Processed chunk #898. Got 6705 insts
# Processed chunk #900. Got 6752 insts
# Processed chunk #901. Got 6781 insts
# Processed chunk #899. Got 6812 insts
# Processed chunk #902. Got 6849 insts
# Processed chunk #905. Got 6880 insts
# Processed chunk #904. Got 6903 insts
# Processed chunk #903. Got 6940 insts
# Processed chunk #906. Got 6978 insts
# Processed chunk #907. Got 7014 insts
# Processed chunk #908. Got 7045 insts
# Processed chunk #909. Got 7086 insts
# Processed chunk #910. Got 7109 insts
# Processed chunk #911. Got 7138 insts
# Processed chunk #912. Got 7172 insts
# Processed chunk #913. Got 7202 insts
# Processed chunk #914. Got 7236 insts
# Processed chunk #916. Got 7269 insts
# Processed chunk #917. Got 7313 insts
# Processed chunk #915. Got 7341 insts
# Processed chunk #918. Got 7377 insts
# Processed chunk #919. Got 7415 insts
# Processed chunk #920. Got 7450 insts
# Processed chunk #922. Got 7461 insts
# Processed chunk #921. Got 7512 insts
# Processed chunk #923. Got 7546 insts
# Processed chunk #924. Got 7578 insts
# Processed chunk #925. Got 7611 insts
# Processed chunk #926. Got 7644 insts
# Processed chunk #979. Got 7684 insts
# Processed chunk #929. Got 7715 insts
# Processed chunk #928. Got 7733 insts
# Processed chunk #930. Got 7761 insts
# Processed chunk #931. Got 7782 insts
# Processed chunk #932. Got 7811 insts
# Processed chunk #933. Got 7849 insts
# Processed chunk #934. Got 7884 insts
# Processed chunk #935. Got 7918 insts
# Processed chunk #936. Got 7949 insts
# Processed chunk #937. Got 7992 insts
# Processed chunk #1157. Got 8026 insts
# Processed chunk #1159. Got 8066 insts
# Processed chunk #1158. Got 8103 insts
# Processed chunk #1160. Got 8116 insts
# Processed chunk #1161. Got 8160 insts
# Processed chunk #1162. Got 8188 insts
# Processed chunk #1163. Got 8222 insts
# Processed chunk #1164. Got 8247 insts
# Processed chunk #1165. Got 8278 insts
